# %% [markdown]
# ![AEE309DF-A8B1-45B8-BEC6-143ED94EFB11_4_5005_c.jpeg](attachment:AEE309DF-A8B1-45B8-BEC6-143ED94EFB11_4_5005_c.jpeg)

# %% [markdown]
# # PYTHON BASICS REFRESH (10 Oct 22)

# %% [markdown]
# __These challenges are prepared to refresh your Python Basics knowledge and hands-on experience. At first, please try to solve these challenges with your own. Challenge-4 is optional. If you have time to solve it, and want to solve it, then solve it!☺️ Best Luck!✌️🦾__

# %% [markdown]
# ## Challenge-1 (Economic Freedom Rank)

# %% [markdown]
# ### Task:

# %% [markdown]
# __You are working on data that represents the economic freedom rank by country.
# Each country name and rank are stored in a dictionary, with the key being the country name.__
#
# __Complete the program to take the country name as input and output its corresponding economic freedom rank.
# In case the provided country name is not present in the data, output "Not found".__

# %% [markdown]
# __Recall the get() method of a dictionary, that allows you to specify a default value.__<br>
#
#
# __Sample Input<br>
# Italy__<br><br>
# __Sample Output<br>
# 74__

# %% [markdown]
# ### Your solution:

# %%
# Your code here
data = {
    'Singapore': 1,
    'Ireland': 6,
    'United Kingdom': 7,
    'Germany': 27,
    'Armenia': 34,
    'United States': 17,
    'Canada': 9,
    'Italy': 74
}     
# please finalize the code

# %% [markdown]
# ## Challenge-2 (Date Picker)

# %% [markdown]
# ### Task:

# %% [markdown]
# __You are creating a date picker for a website and need to output all of the years in a given period.
# Write a program that takes two integers as input and outputs the range of numbers between the two inputs as a list.
# The output sequence should start with the first input number and end with the second input number, without including it.__
#
# __Sample Input
# 2005
# 2011__
#
# __Sample Output
# [2005, 2006, 2007, 2008, 2009, 2010]__

# %% [markdown]
# ### Your solution:

# %%
# Your code here

# %% [markdown]
# ## Challenge-3 (Numbers Backwards)

# %% [markdown]
# ### Task:

# %% [markdown]
# __Given a string as input, use recursion to output each letter of the strings in reverse order, on a new line.__<br><br>

# %% [markdown]
# Sample Input<br>
# HELLO<br><br>
#
# Sample Output<br>
# O<br>
# L<br>
# L<br>
# E<br>
# H<br><br><br>
#
# __Complete the recursive spell() function to produce the expected result.__

# %% [markdown]
# ### Your solution:

# %%
# Your code here

def spell(txt):   # please complete the function

# %%
spell(txt)  # and test and run it here

# %% [markdown]
# ## Challenge-4 (Prime Number Finder)(Optional)

# %% [markdown]
# ### Task:

# %% [markdown]
# __Create a prime_finder() function that takes in a number, n, and returns all the prime numbers from 1 to n (inclusive) in a list.__<br> <br>
# __As a reminder, a prime number is a number that is only divisible by 1 and itself.__
#
# __For example, prime_finder(11) should return [2, 3, 5, 7, 11].__

# %% [markdown]
# ### Your solution:

# %%
# Your code here
def prime_finder(n) :  # please complete the function

# %%
prime_finder(n)   # and test and run it here

# %% [markdown]
# ## Pre-class reading

# %% [markdown]
#  __You can find below links of 3 articles regarding Python Basics, two in Turkish, one in English. I strongly recommend you to read these articles before in-class. Enjoy! 📚 👩‍💻 🧑‍💻__

# %% [markdown]
# ** Learning Python: From Zero to Hero **<br>
# https://www.iamtk.co/learning-python-from-zero-to-hero<br><br>
# ** Python Öğreniyoruz, Bölüm-1 **<br>
# https://medium.com/@haticecandan/python-%C3%B6%C4%9Freniyoruz-b%C3%B6l%C3%BCm-1-pythona-giri%C5%9F-veri-yap%C4%B1lar%C4%B1-operat%C3%B6rler-ve-d%C3%B6ng%C3%BCler-64ab8b5e291c<br><br>
# ** Python Öğreniyoruz, Bölüm-2 **<br>
# https://medium.com/@haticecandan/python-%C3%B6%C4%9Freniyoruz-b%C3%B6l%C3%BCm-2-fonksiyonlar-460267177c0d

# %% [markdown]
# *** Guys, you may know that there is no limited access to medium articles which is very fruitful for us.
# Please see below the video that shows us how to read medium articles unlimitedly. Between us!🤫😉 ***  <br>
# https://www.youtube.com/watch?v=m_pj_8xs15o

# %% [markdown]
# ### "The greatest pleasure in life is doing what people say you can't do"

# %% [markdown]
# ![0E52C823-C53F-4612-B75B-A42CD27C1AAF_4_5005_c.jpeg](attachment:0E52C823-C53F-4612-B75B-A42CD27C1AAF_4_5005_c.jpeg)
